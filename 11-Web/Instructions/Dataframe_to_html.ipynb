# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Resources/baig_cities.csv")
df.head()
# Out:
#              City  Latitude  Longitude  Temperature  Feels Like  Humidity  \
# 0        Bengkulu     -3.80     102.27        75.42       80.76        84
# 1             Eyl      7.98      49.82        76.32       75.34        66
# 2    Ponta do Sol     32.67     -17.10        59.02       53.26        59
# 3       Zavetnoye     47.12      43.89        46.42       34.70        69
# 4  Port Elizabeth    -33.92      25.57        57.20       54.97        87
#
#    Pressure  Wind Speed  Cloudiness
# 0      1011        4.27          63
# 1      1013       10.42          63
# 2      1014        8.05          63
# 3      1014       15.82          63
# 4      1011        5.82          63

# %%
print(df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Feels Like</th>
#       <th>Humidity</th>
#       <th>Pressure</th>
#       <th>Wind Speed</th>
#       <th>Cloudiness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Bengkulu</td>
#       <td>-3.80</td>
#       <td>102.27</td>
#       <td>75.42</td>
#       <td>80.76</td>
#       <td>84</td>
#       <td>1011</td>
#       <td>4.27</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <td>Eyl</td>
#       <td>7.98</td>
#       <td>49.82</td>
#       <td>76.32</td>
#       <td>75.34</td>
#       <td>66</td>
#       <td>1013</td>
#       <td>10.42</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <td>Ponta do Sol</td>
#       <td>32.67</td>
#       <td>-17.10</td>
#       <td>59.02</td>
#       <td>53.26</td>
#       <td>59</td>
#       <td>1014</td>
# ...
